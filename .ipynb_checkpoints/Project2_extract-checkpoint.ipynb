# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from datetime import datetime
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
company_data = pd.read_csv("company_data.csv")
ticker_data = pd.read_csv("ticker_data.csv")

# %%
company_data.head()
# Out:
#   ticker dimension calendardate     datekey reportperiod lastupdated  \
# 0    XOM       MRY   2018-12-31  2018-12-31   2018-12-31  2019-05-02
# 1    XOM       MRY   2017-12-31  2017-12-31   2017-12-31  2019-05-02
# 2    XOM       MRY   2016-12-31  2016-12-31   2016-12-31  2019-05-02
# 3    XOM       MRY   2015-12-31  2015-12-31   2015-12-31  2019-05-02
# 4    XOM       MRY   2014-12-31  2014-12-31   2014-12-31  2019-05-02
#
#         accoci        assets     assetsavg       assetsc       ...        \
# 0 -19564000000  346196000000  349610000000  4.797300e+10       ...
# 1 -16262000000  348691000000  346334750000  4.713400e+10       ...
# 2 -22239000000  330314000000  338740500000  4.141600e+10       ...
# 3 -23511000000  336758000000  342160250000  4.262300e+10       ...
# 4 -18957000000  349493000000  353469000000  5.291000e+10       ...
#
#     sharesbas    shareswa  shareswadil     sps     tangibles  taxassets  \
# 0  4233807170  4233807170          NaN  68.546  346196000000          0
# 1  4237106077  4237106077          NaN  57.672  348691000000          0
# 2  4146693326  4146693326          NaN  50.188  330314000000          0
# 3  4162938512  4162938512          NaN  59.873  336758000000          0
# 4  4234528643  4234528643          NaN  97.281  349493000000          0
#
#         taxexp  taxliabilities   tbvps  workingcapital
# 0   9532000000     29856000000  81.769   -9.165000e+09
# 1  -1174000000     29938000000  82.295   -1.063700e+10
# 2   -406000000     36656000000  79.657   -6.222000e+09
# 3   5415000000     39620000000  80.894   -1.135300e+10
# 4  18015000000     44168000000  82.534   -1.172300e+10
#
# [5 rows x 111 columns]

# %%
# #transform company_data
# company_clean = company_data.reset_index(drop=True)
# company_cols = company_clean[["ticker","calendardate","assetturnover","currentratio","de","epsusd","grossmargin",
#                              "netmargin","pe","price"]]
# company_cols.head()

# %%
#ticker data
ticker_data.head()
# Out:
#   table  permaticker ticker                                  name exchange  \
# 0   SF1       196290      A              Agilent Technologies Inc     NYSE
# 1   SF1       124392     AA                            Alcoa Corp     NYSE
# 2   SF1       122827   AAAB                 Admiralty Bancorp Inc   NASDAQ
# 3   SF1       120538  AAAGY             Altana Aktiengesellschaft     NYSE
# 4   SF1       155760   AAAP  Advanced Accelerator Applications SA   NASDAQ
#
#   isdelisted  category     cusips  siccode                          sicsector  \
# 0          N  Domestic  00846U101   3826.0                      Manufacturing
# 1          N  Domestic  013872106   3350.0                      Manufacturing
# 2          Y  Domestic  007231103   6022.0  Finance Insurance And Real Estate
# 3          Y       ADR  02143N103   2834.0                      Manufacturing
# 4          Y       ADR  00790T100   2834.0                      Manufacturing
#
#             ...           currency          location lastupdated  firstadded  \
# 0           ...                USD  California U.S.A  2019-05-30  2014-09-26
# 1           ...                USD    New York U.S.A  2019-05-09  2016-11-01
# 2           ...                USD     Florida U.S.A  2018-10-16  2017-09-09
# 3           ...                EUR            Jordan  2019-05-17  2018-02-13
# 4           ...                EUR            France  2017-07-17  2016-05-19
#
#   firstpricedate lastpricedate firstquarter lastquarter  \
# 0     1999-11-18    2019-06-11   1997-06-30  2019-03-31
# 1     2016-11-01    2019-06-11   2014-12-31  2019-03-31
# 2     1998-09-28    2003-01-29   1997-09-30  2002-09-30
# 3     2002-05-22    2010-08-12   2000-12-31  2005-12-31
# 4     2015-11-11    2018-02-09   2013-12-31  2016-12-31
#
#                                           secfilings             companysite
# 0  https://www.sec.gov/cgi-bin/browse-edgar?actio...  http://www.agilent.com
# 1  https://www.sec.gov/cgi-bin/browse-edgar?actio...    http://www.alcoa.com
# 2  https://www.sec.gov/cgi-bin/browse-edgar?actio...                     NaN
# 3  https://www.sec.gov/cgi-bin/browse-edgar?actio...                     NaN
# 4  https://www.sec.gov/cgi-bin/browse-edgar?actio...                     NaN
#
# [5 rows x 28 columns]

# %%
# #transform ticker data
# ticker_cols = ticker_data[["ticker","name", "category","sicsector","currency","location","sector"]]
# ticker_cols.head()

# %%
# #Create connection
# rds_connection_string = "root:##Kk26agro@127.0.0.1/company_db"
# engine = create_engine(f'mysql://{rds_connection_string}')

# %%
# engine.table_names()

# %%
# #export company_cols table into sql
# company_cols.to_sql(name='company', con=engine, if_exists='append', index=False)

# %%
# #export ticker_cols table into sql
# ticker_cols.to_sql(name='ticker', con=engine, if_exists='append', index=False)

# %%
#create engine from project2.sqlite
engine = create_engine("sqlite:///project2.sqlite")

# %%
conn = engine.connect()

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# []

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'measurement'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a85ad09ce628> in <module>
#       1 # Save references to each table
# ----> 2 Measurement = Base.classes.measurement
#       3 Station = Base.classes.station
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: measurement
